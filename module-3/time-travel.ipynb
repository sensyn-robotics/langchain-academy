# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/time-travel.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239536-lesson-5-time-travel)

# %% [markdown]
# # Time travel
#
# ## Review
#
# We discussed motivations for human-in-the-loop:
#
# (1) `Approval` - We can interrupt our agent, surface state to a user, and allow the user to accept an action
#
# (2) `Debugging` - We can rewind the graph to reproduce or avoid issues
#
# (3) `Editing` - You can modify the state
#
# We showed how breakpoints can stop the graph at specific nodes or allow the graph to dynamically interrupt itself.
#
# Then we showed how to proceed with human approval or directly edit the graph state with human feedback.
#
# ## Goals
#
# Now, let's show how LangGraph [supports debugging](https://langchain-ai.github.io/langgraph/how-tos/human_in_the_loop/time-travel/) by viewing, re-playing, and even forking from past states.
#
# We call this `time travel`.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk langgraph-prebuilt

# %%
# import os, getpass

# def _set_env(var: str):
#     if not os.environ.get(var):
#         os.environ[var] = getpass.getpass(f"{var}: ")

# _set_env("OPENAI_API_KEY")

# %%
import os
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %% [markdown]
# Let's build our agent.

# %%
from langchain_openai import ChatOpenAI

def multiply(a: int, b: int) -> int:
    """Multiply a and b.

    Args:
        a: first int
        b: second int
    """
    return a * b

# This will be a tool
def add(a: int, b: int) -> int:
    """Adds a and b.

    Args:
        a: first int
        b: second int
    """
    return a + b

def divide(a: int, b: int) -> float:
    """Divide a by b.

    Args:
        a: first int
        b: second int
    """
    return a / b

tools = [add, multiply, divide]
llm = ChatOpenAI(model="gpt-4o")
llm_with_tools = llm.bind_tools(tools)

# %%
from IPython.display import Image, display

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import MessagesState
from langgraph.graph import START, END, StateGraph
from langgraph.prebuilt import tools_condition, ToolNode

from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

# System message
sys_msg = SystemMessage(content="You are a helpful assistant tasked with performing arithmetic on a set of inputs.")

# Node
def assistant(state: MessagesState):
   return {"messages": [llm_with_tools.invoke([sys_msg] + state["messages"])]}

# Graph
builder = StateGraph(MessagesState)

# Define nodes: these do the work
builder.add_node("assistant", assistant)
builder.add_node("tools", ToolNode(tools))

# Define edges: these determine the control flow
builder.add_edge(START, "assistant")
builder.add_conditional_edges(
    "assistant",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition,
)
builder.add_edge("tools", "assistant")

memory = MemorySaver()
graph = builder.compile(checkpointer=MemorySaver())

# Show
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# Let's run it, as before.

# %%
# Input
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}

# Thread
thread = {"configurable": {"thread_id": "1"}}

# Run the graph until the first interruption
for event in graph.stream(initial_input, thread, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_RmIA8WAzqywGqiB82fbnuNuX)
#  Call ID: call_RmIA8WAzqywGqiB82fbnuNuX
#   Args:
#     a: 2
#     b: 3
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The result of multiplying 2 and 3 is 6.

# %% [markdown]
# ## Browsing History
#
# We can use `get_state` to look at the **current** state of our graph, given the `thread_id`!

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='34dfca9e-6a7c-41fc-9cd7-9dc3398818c3'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_RmIA8WAzqywGqiB82fbnuNuX', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 131, 'total_tokens': 149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_d8864f8b6b', 'id': 'chatcmpl-BSdis0MAYLiY5nKU4bm4T4XoN3Hl9', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c367f855-2bbe-48a1-bba0-fa8358e050df-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_RmIA8WAzqywGqiB82fbnuNuX', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 18, 'total_tokens': 149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='6', name='multiply', id='301b2b31-56a0-446c-81db-57aa2d373a57', tool_call_id='call_RmIA8WAzqywGqiB82fbnuNuX'), AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 156, 'total_tokens': 171, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_d8864f8b6b', 'id': 'chatcmpl-BSditTIPakMWN7ybwyQekq7EFG9x4', 'finish_reason': 'stop', 'logprobs': None}, id='run-52b1c5e9-2948-49cc-9c49-78d11203d98f-0', usage_metadata={'input_tokens': 156, 'output_tokens': 15, 'total_tokens': 171, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271aa-26c7-607b-8003-3147c41f4584'}}, metadata={'source': 'loop', 'writes': {'assistant': {'messages': [AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 156, 'total_tokens': 171, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_d8864f8b6b', 'id': 'chatcmpl-BSditTIPakMWN7ybwyQekq7EFG9x4', 'finish_reason': 'stop', 'logprobs': None}, id='run-52b1c5e9-2948-49cc-9c49-78d11203d98f-0', usage_metadata={'input_tokens': 156, 'output_tokens': 15, 'total_tokens': 171, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'step': 3, 'parents': {}, 'thread_id': '1'}, created_at='2025-05-02T05:59:39.613385+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271aa-2167-62f4-8002-a9dcdd8a31e6'}}, tasks=())

# %% [markdown]
# We can also browse the state history of our agent.
#
# `get_state_history` lets us get the state at all prior steps.

# %%
all_states = [s for s in graph.get_state_history(thread)]

# %%
len(all_states)
# Out:
# 5

# %% [markdown]
# The first element is the current state, just as we got from `get_state`.

# %%
all_states[-2]
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='34dfca9e-6a7c-41fc-9cd7-9dc3398818c3')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271aa-1956-6ac9-8000-605fcb5ccb74'}}, metadata={'source': 'loop', 'writes': None, 'step': 0, 'parents': {}, 'thread_id': '1'}, created_at='2025-05-02T05:59:38.204220+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271aa-1954-6c55-bfff-8e5753414e45'}}, tasks=(PregelTask(id='d04382e8-b34a-d325-43d3-a18b9d3c9e47', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_RmIA8WAzqywGqiB82fbnuNuX', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 131, 'total_tokens': 149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_d8864f8b6b', 'id': 'chatcmpl-BSdis0MAYLiY5nKU4bm4T4XoN3Hl9', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c367f855-2bbe-48a1-bba0-fa8358e050df-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_RmIA8WAzqywGqiB82fbnuNuX', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 18, 'total_tokens': 149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}),))

# %% [markdown]
# Everything above we can visualize here:
#
# ![fig1.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038211b544898570be3_time-travel1.png)

# %% [markdown]
# ## Replaying
#
# We can re-run our agent from any of the prior steps.
#
# ![fig2.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038a0bd34b541c78fb8_time-travel2.png)

# %% [markdown]
# Let's look back at the step that recieved human input!

# %%
to_replay = all_states[-2]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='34dfca9e-6a7c-41fc-9cd7-9dc3398818c3')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271aa-1956-6ac9-8000-605fcb5ccb74'}}, metadata={'source': 'loop', 'writes': None, 'step': 0, 'parents': {}, 'thread_id': '1'}, created_at='2025-05-02T05:59:38.204220+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271aa-1954-6c55-bfff-8e5753414e45'}}, tasks=(PregelTask(id='d04382e8-b34a-d325-43d3-a18b9d3c9e47', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_RmIA8WAzqywGqiB82fbnuNuX', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 131, 'total_tokens': 149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_d8864f8b6b', 'id': 'chatcmpl-BSdis0MAYLiY5nKU4bm4T4XoN3Hl9', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-c367f855-2bbe-48a1-bba0-fa8358e050df-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_RmIA8WAzqywGqiB82fbnuNuX', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 18, 'total_tokens': 149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}),))

# %% [markdown]
# Look at the state.

# %%
to_replay.values
# Out:
# {'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='34dfca9e-6a7c-41fc-9cd7-9dc3398818c3')]}

# %% [markdown]
# We can see the next node to call.

# %%
to_replay.next
# Out:
# ('assistant',)

# %% [markdown]
# We also get the config, which tells us the `checkpoint_id` as well as the `thread_id`.

# %%
to_replay.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0271aa-1956-6ac9-8000-605fcb5ccb74'}}

# %% [markdown]
# To replay from here, we simply pass the config back to the agent!
#
# The graph knows that this checkpoint has aleady been executed.
#
# It just re-plays from this checkpoint!

# %%
for event in graph.stream(None, to_replay.config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_YyQkWqe80viLA6RypajvQcfk)
#  Call ID: call_YyQkWqe80viLA6RypajvQcfk
#   Args:
#     a: 2
#     b: 3
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The result of multiplying 2 and 3 is 6.

# %% [markdown]
# Now, we can see our current state after the agent re-ran.

# %% [markdown]
# ## Forking
#
# What if we want to run from that same step, but with a different input.
#
# This is forking.
#
# ![fig3.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038f89f2d847ee5c336_time-travel3.png)

# %%
to_fork = all_states[-2]
to_fork.values["messages"]
# Out:
# [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='34dfca9e-6a7c-41fc-9cd7-9dc3398818c3')]

# %% [markdown]
# Again, we have the config.

# %%
to_fork.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0271aa-1956-6ac9-8000-605fcb5ccb74'}}

# %% [markdown]
# Let's modify the state at this checkpoint.
#
# We can just run `update_state` with the `checkpoint_id` supplied.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!
#
# So, to overwrite the the message, we just supply the message ID, which we have `to_fork.values["messages"].id`.

# %%
fork_config = graph.update_state(
    to_fork.config,
    {"messages": [HumanMessage(content='Multiply 5 and 3', 
                               id=to_fork.values["messages"][0].id)]},
)

# %%
fork_config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0271c4-bfa7-68f7-8001-6d59396a015f'}}

# %% [markdown]
# This creates a new, forked checkpoint.
#
# But, the metadata - e.g., where to go next - is perserved!
#
# We can see the current state of our agent has been updated with our fork.

# %%
all_states = [state for state in graph.get_state_history(thread) ]
all_states[0].values["messages"]
# Out:
# [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='34dfca9e-6a7c-41fc-9cd7-9dc3398818c3')]

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='34dfca9e-6a7c-41fc-9cd7-9dc3398818c3')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271c4-bfa7-68f7-8001-6d59396a015f'}}, metadata={'source': 'update', 'writes': {'__start__': {'messages': [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='34dfca9e-6a7c-41fc-9cd7-9dc3398818c3')]}}, 'step': 1, 'parents': {}, 'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271aa-1956-6ac9-8000-605fcb5ccb74'}, created_at='2025-05-02T06:11:33.575891+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271aa-1956-6ac9-8000-605fcb5ccb74'}}, tasks=(PregelTask(id='29ad0226-acd4-c989-41b2-da2ff60e4888', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result=None),))

# %% [markdown]
# Now, when we stream, the graph knows this checkpoint has never been executed.
#
# So, the graph runs, rather than simply re-playing.

# %%
for event in graph.stream(None, fork_config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 5 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_vTZH0N7GGQxkDMZy27M9xDIs)
#  Call ID: call_vTZH0N7GGQxkDMZy27M9xDIs
#   Args:
#     a: 5
#     b: 3
# ================================= Tool Message =================================
# Name: multiply
#
# 15
# ================================== Ai Message ==================================
#
# The result of multiplying 5 and 3 is 15.

# %% [markdown]
# Now, we can see the current state is the end of our agent run.

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='34dfca9e-6a7c-41fc-9cd7-9dc3398818c3'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_vTZH0N7GGQxkDMZy27M9xDIs', 'function': {'arguments': '{"a":5,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 18, 'prompt_tokens': 131, 'total_tokens': 149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_d8864f8b6b', 'id': 'chatcmpl-BSdvYjZOyxK1zLFzlLT2lJeyDZBYi', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-3cf1b588-262d-41a4-8c87-7220e083172b-0', tool_calls=[{'name': 'multiply', 'args': {'a': 5, 'b': 3}, 'id': 'call_vTZH0N7GGQxkDMZy27M9xDIs', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 18, 'total_tokens': 149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='15', name='multiply', id='30bb31dd-c738-459d-a4d4-ee11ced04b8b', tool_call_id='call_vTZH0N7GGQxkDMZy27M9xDIs'), AIMessage(content='The result of multiplying 5 and 3 is 15.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 156, 'total_tokens': 171, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_d8864f8b6b', 'id': 'chatcmpl-BSdvZov7dlGwAVvR8JAK7gYeXAfNw', 'finish_reason': 'stop', 'logprobs': None}, id='run-96802ad1-7c66-49cb-ac44-b3f8c3656c65-0', usage_metadata={'input_tokens': 156, 'output_tokens': 15, 'total_tokens': 171, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271c7-7190-6e1a-8004-3c0abb1b5983'}}, metadata={'source': 'loop', 'writes': {'assistant': {'messages': [AIMessage(content='The result of multiplying 5 and 3 is 15.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 156, 'total_tokens': 171, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_d8864f8b6b', 'id': 'chatcmpl-BSdvZov7dlGwAVvR8JAK7gYeXAfNw', 'finish_reason': 'stop', 'logprobs': None}, id='run-96802ad1-7c66-49cb-ac44-b3f8c3656c65-0', usage_metadata={'input_tokens': 156, 'output_tokens': 15, 'total_tokens': 171, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}}, 'step': 4, 'parents': {}, 'thread_id': '1'}, created_at='2025-05-02T06:12:45.918342+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0271c7-6c21-6d2a-8003-67a591e3970f'}}, tasks=())

# %% [markdown]
# ### Time travel with LangGraph API
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
#
# We connect to it via the SDK and show how the LangGraph API [supports time travel](https://langchain-ai.github.io/langgraph/cloud/how-tos/human_in_the_loop_time_travel/#initial-invocation).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client
client = get_client(url="http://127.0.0.1:2024")

# %% [markdown]
# #### Re-playing
#
# Let's run our agent streaming `updates` to the state of the graph after each node is called.

# %%
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id = "agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_6kpw6t3dAoidYgmjV3c1EYur', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 134, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdxVIXLvHT9TkxOoz1qcxpTSNiTi', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-96b10bfa-f8a3-4c04-9f15-d2d065f075a3-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_6kpw6t3dAoidYgmjV3c1EYur', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 18, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'd5104e10-8ee8-49cd-8a57-bc10aea9b0d0', 'tool_call_id': 'call_6kpw6t3dAoidYgmjV3c1EYur', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 15, 'prompt_tokens': 159, 'total_tokens': 174, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdxWFgPF5Akt6idXpBkk2VeCcWAf', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-1396e050-84b7-4721-b625-a941e4ecc06e-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 15, 'total_tokens': 174, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}

# %% [markdown]
# Now, let's look at **replaying** from a specified checkpoint.
#
# We simply need to pass the `checkpoint_id`.

# %%
states = await client.threads.get_history(thread['thread_id'])
to_replay = states[-2]
to_replay
# Out:
# {'values': {'messages': [{'content': 'Multiply 2 and 3',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': 'a45d29e4-ae54-4335-b93a-e4a6e3ae7e1a',
#     'example': False}]},
#  'next': ['assistant'],
#  'tasks': [{'id': 'd01f6e26-35e2-6c0a-7835-17580ec1e8cc',
#    'name': 'assistant',
#    'path': ['__pregel_pull', 'assistant'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': {'messages': [{'content': '',
#       'additional_kwargs': {'tool_calls': [{'id': 'call_6kpw6t3dAoidYgmjV3c1EYur',
#          'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'},
#          'type': 'function'}],
#        'refusal': None},
#       'response_metadata': {'token_usage': {'completion_tokens': 18,
#         'prompt_tokens': 134,
#         'total_tokens': 152,
#         'completion_tokens_details': {'accepted_prediction_tokens': 0,
#          'audio_tokens': 0,
#          'reasoning_tokens': 0,
#          'rejected_prediction_tokens': 0},
#         'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#        'model_name': 'gpt-4o-2024-08-06',
#        'system_fingerprint': 'fp_55d88aaf2f',
#        'id': 'chatcmpl-BSdxVIXLvHT9TkxOoz1qcxpTSNiTi',
#        'finish_reason': 'tool_calls',
#        'logprobs': None},
#       'type': 'ai',
#       'name': None,
#       'id': 'run-96b10bfa-f8a3-4c04-9f15-d2d065f075a3-0',
#       'example': False,
#       'tool_calls': [{'name': 'multiply',
#         'args': {'a': 2, 'b': 3},
#         'id': 'call_6kpw6t3dAoidYgmjV3c1EYur',
#         'type': 'tool_call'}],
#       'invalid_tool_calls': [],
#       'usage_metadata': {'input_tokens': 134,
#        'output_tokens': 18,
#        'total_tokens': 152,
#        'input_token_details': {'audio': 0, 'cache_read': 0},
#        'output_token_details': {'audio': 0, 'reasoning': 0}}}]}}],
#  'metadata': {'user-agent': 'langgraph-sdk-py/0.1.61',
#   'langgraph_auth_user': None,
#   'langgraph_auth_user_id': '',
#   'langgraph_auth_permissions': [],
#   'graph_id': 'agent',
#   'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#   'user_id': '',
#   'created_by': 'system',
#   'run_attempt': 1,
#   'langgraph_version': '0.3.29',
#   'langgraph_plan': 'developer',
#   'langgraph_host': 'self-hosted',
#   'langgraph_api_url': 'http://127.0.0.1:2024',
#   'run_id': '1f0271cb-dffc-6486-9acb-365bbc188e68',
#   'thread_id': 'c2c937f6-3bc3-4d27-a4e8-9a1a31cc5d61',
#   'source': 'loop',
#   'writes': None,
#   'step': 0,
#   'parents': {}},
#  'created_at': '2025-05-02T06:14:45.417301+00:00',
#  'checkpoint': {'checkpoint_id': '1f0271cb-e532-6646-8000-919df9cc8ebb',
#   'thread_id': 'c2c937f6-3bc3-4d27-a4e8-9a1a31cc5d61',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f0271cb-e52a-673a-bfff-b302fd846a51',
#   'thread_id': 'c2c937f6-3bc3-4d27-a4e8-9a1a31cc5d61',
#   'checkpoint_ns': ''},
#  'checkpoint_id': '1f0271cb-e532-6646-8000-919df9cc8ebb',
#  'parent_checkpoint_id': '1f0271cb-e52a-673a-bfff-b302fd846a51'}

# %% [markdown]
# Let's stream with `stream_mode="values"` to see the full state at every node as we replay.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="values",
    checkpoint_id=to_replay['checkpoint_id']
):      
    print(f"Receiving new event of type: {chunk.event}...")
    print(chunk.data)
    print("\n\n")
# Out:
# Receiving new event of type: metadata...
# {'run_id': '1f0271ce-9785-6b85-9e1e-abd57ed3da6c', 'attempt': 1}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'a45d29e4-ae54-4335-b93a-e4a6e3ae7e1a', 'example': False}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'a45d29e4-ae54-4335-b93a-e4a6e3ae7e1a', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_rjQnVCpeKRWjXyjirD1HpyUR', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 134, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdygYWTRyEBrr4McFRkBgOXxv8UD', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-57169780-4fbd-41e2-8062-1f42a4d5cd92-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_rjQnVCpeKRWjXyjirD1HpyUR', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 18, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'a45d29e4-ae54-4335-b93a-e4a6e3ae7e1a', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_rjQnVCpeKRWjXyjirD1HpyUR', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 134, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdygYWTRyEBrr4McFRkBgOXxv8UD', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-57169780-4fbd-41e2-8062-1f42a4d5cd92-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_rjQnVCpeKRWjXyjirD1HpyUR', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 18, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'ee5cd2af-0ab1-4682-bec2-cec675e4c2a0', 'tool_call_id': 'call_rjQnVCpeKRWjXyjirD1HpyUR', 'artifact': None, 'status': 'success'}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'a45d29e4-ae54-4335-b93a-e4a6e3ae7e1a', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_rjQnVCpeKRWjXyjirD1HpyUR', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 134, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdygYWTRyEBrr4McFRkBgOXxv8UD', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-57169780-4fbd-41e2-8062-1f42a4d5cd92-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_rjQnVCpeKRWjXyjirD1HpyUR', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 18, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'ee5cd2af-0ab1-4682-bec2-cec675e4c2a0', 'tool_call_id': 'call_rjQnVCpeKRWjXyjirD1HpyUR', 'artifact': None, 'status': 'success'}, {'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 15, 'prompt_tokens': 159, 'total_tokens': 174, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdyhj7Map4DeFLJ4nBz9hZq6i3Tx', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-eae33324-ac03-49ef-a0ae-9b958c68e5cd-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 15, 'total_tokens': 174, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]}

# %% [markdown]
# We can all view this as streaming only `updates` to state made by the nodes that we reply.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=to_replay['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_iGhtxLAHKSUVZxqn6Q9x75h6', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 134, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdzF8eTLeyDtgawAneqijxk1z17D', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-f236b11c-4fbe-47d1-ae5a-9a21b542a290-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_iGhtxLAHKSUVZxqn6Q9x75h6', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 18, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '3f722555-7d27-4942-a735-368e0eea7ddc', 'tool_call_id': 'call_iGhtxLAHKSUVZxqn6Q9x75h6', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The product of 2 and 3 is 6.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 14, 'prompt_tokens': 159, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdzF1dLynmkqMyNk5ImkGE6C7DGV', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-9ad171a1-2b3a-4f2b-bed3-d8d773459c25-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 14, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}

# %% [markdown]
# #### Forking
#
# Now, let's look at forking.
#
# Let's get the same step as we worked with above, the human input.
#
# Let's create a new thread with our agent.

# %%
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_Hjq8vw2D2IoAsFsxgvRapyJN', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 134, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdzYtpxYHZ5tjwcQToqIuF0jhWuR', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-8e8cbac4-f98b-4ea8-92b4-3867d85e37a5-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_Hjq8vw2D2IoAsFsxgvRapyJN', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 18, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '1e58b950-588d-4006-ab21-f1a9ade9e5be', 'tool_call_id': 'call_Hjq8vw2D2IoAsFsxgvRapyJN', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 15, 'prompt_tokens': 159, 'total_tokens': 174, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSdzZphrSxH86a0FIaC4FwgV9DSAo', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-58faa04d-939d-4f65-99ec-513a60c329c7-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 15, 'total_tokens': 174, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}

# %%
states = await client.threads.get_history(thread['thread_id'])
to_fork = states[-2]
to_fork['values']
# Out:
# {'messages': [{'content': 'Multiply 2 and 3',
#    'additional_kwargs': {},
#    'response_metadata': {},
#    'type': 'human',
#    'name': None,
#    'id': 'c6bddea8-cb2d-4b1c-924d-fec8c78141b4',
#    'example': False}]}

# %%
to_fork['values']['messages'][0]['id']
# Out:
# 'c6bddea8-cb2d-4b1c-924d-fec8c78141b4'

# %%
to_fork['next']
# Out:
# ['assistant']

# %%
to_fork['checkpoint_id']
# Out:
# '1f0271d0-9e54-6ac7-8000-3934bec519cf'

# %% [markdown]
# Let's edit the state.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!

# %%
forked_input = {"messages": HumanMessage(content="Multiply 3 and 3",
                                         id=to_fork['values']['messages'][0]['id'])}

forked_config = await client.threads.update_state(
    thread["thread_id"],
    forked_input,
    checkpoint_id=to_fork['checkpoint_id']
)

# %%
forked_config
# Out:
# {'checkpoint': {'thread_id': 'd32bfd77-857d-44fe-a78b-0ed5261be322',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0271d3-c422-6e0f-8001-00e5089665bc'},
#  'configurable': {'thread_id': 'd32bfd77-857d-44fe-a78b-0ed5261be322',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0271d3-c422-6e0f-8001-00e5089665bc'},
#  'checkpoint_id': '1f0271d3-c422-6e0f-8001-00e5089665bc'}

# %%
states = await client.threads.get_history(thread['thread_id'])
states[0]
# Out:
# {'values': {'messages': [{'content': 'Multiply 3 and 3',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': 'c6bddea8-cb2d-4b1c-924d-fec8c78141b4',
#     'example': False}]},
#  'next': ['assistant'],
#  'tasks': [{'id': 'e67f095f-0000-2a36-b81c-7cb9197c63fd',
#    'name': 'assistant',
#    'path': ['__pregel_pull', 'assistant'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': None}],
#  'metadata': {'graph_id': 'agent',
#   'thread_id': 'd32bfd77-857d-44fe-a78b-0ed5261be322',
#   'checkpoint_id': '1f0271d0-9e54-6ac7-8000-3934bec519cf',
#   'checkpoint_ns': '',
#   'user-agent': 'langgraph-sdk-py/0.1.61',
#   'langgraph_auth_user': None,
#   'langgraph_auth_user_id': '',
#   'langgraph_auth_permissions': [],
#   'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#   'user_id': '',
#   'created_by': 'system',
#   'run_attempt': 1,
#   'langgraph_version': '0.3.29',
#   'langgraph_plan': 'developer',
#   'langgraph_host': 'self-hosted',
#   'langgraph_api_url': 'http://127.0.0.1:2024',
#   'run_id': '1f0271d0-9926-6fc0-97cf-aa3f1693854b',
#   'source': 'update',
#   'writes': {'__start__': {'messages': {'content': 'Multiply 3 and 3',
#      'additional_kwargs': {},
#      'response_metadata': {},
#      'type': 'human',
#      'name': None,
#      'id': 'c6bddea8-cb2d-4b1c-924d-fec8c78141b4',
#      'example': False}}},
#   'step': 1,
#   'parents': {}},
#  'created_at': '2025-05-02T06:18:16.699002+00:00',
#  'checkpoint': {'checkpoint_id': '1f0271d3-c422-6e0f-8001-00e5089665bc',
#   'thread_id': 'd32bfd77-857d-44fe-a78b-0ed5261be322',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f0271d0-9e54-6ac7-8000-3934bec519cf',
#   'thread_id': 'd32bfd77-857d-44fe-a78b-0ed5261be322',
#   'checkpoint_ns': ''},
#  'checkpoint_id': '1f0271d3-c422-6e0f-8001-00e5089665bc',
#  'parent_checkpoint_id': '1f0271d0-9e54-6ac7-8000-3934bec519cf'}

# %% [markdown]
# To rerun, we pass in the `checkpoint_id`.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=forked_config['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_D01olKr0Be7bBIJHiHIeD34n', 'function': {'arguments': '{"a":3,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 18, 'prompt_tokens': 134, 'total_tokens': 152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSe1mb84VDAB786PRuJFsuxCHXP6r', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-253bca9e-0bb9-4dde-825a-bbb1c2d0566e-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 3, 'b': 3}, 'id': 'call_D01olKr0Be7bBIJHiHIeD34n', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 18, 'total_tokens': 152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '9', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '07feb9fb-fbf2-4e5e-9bbf-0c2b5b6fdb4f', 'tool_call_id': 'call_D01olKr0Be7bBIJHiHIeD34n', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The result of multiplying 3 and 3 is 9.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 15, 'prompt_tokens': 159, 'total_tokens': 174, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSe1mN85Fd5aeOEasX2XsnJq0Grzr', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run-d26f42ef-bbc0-4e19-bf4a-d586ef0f67a4-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 15, 'total_tokens': 174, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}

# %% [markdown]
# ### LangGraph Studio
#
# Let's look at forking in the Studio UI with our `agent`, which uses `module-1/studio/agent.py` set in `module-1/studio/langgraph.json`.
